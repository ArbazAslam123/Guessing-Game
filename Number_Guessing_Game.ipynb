# %%
import random
print("Welcome to Guessing Game:")
a=int(input("Enter your number from 1 to 100 :"))
b=random.randint(1,100)
print("Computer number is :",b)
if a == b:
  print("you guess the correct number")
elif a < b :
  print("you guess number is too low")
elif a > b:
  print("you guess number is too large")
# Out:
# Welcome to Guessing Game:
# Enter your number from 1 to 100 :99
# Computer number is : 61
# you guess larger number
